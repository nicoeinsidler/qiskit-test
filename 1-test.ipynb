# %%
# First Qiskit Test

## Importing Qiskit
# Out:
#   File "<ipython-input-34-053ce8056fb3>", line 1
#     $\usepackage{\physics}$
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import qiskit
import numpy as np
import matplotlib

qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.11.1',
#  'qiskit-aer': '0.3.4',
#  'qiskit-ignis': '0.2.0',
#  'qiskit-ibmq-provider': '0.4.5',
#  'qiskit-aqua': '0.6.2',
#  'qiskit': '0.14.1'}

# %% [markdown]
# ## Defining a Simulation Device

# %%
simulator = qiskit.Aer.get_backend('qasm_simulator')

# %% [markdown]
# ## Defining a Circuit
#
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
#
# First a new quantum circuit is registered with two qubits. Afterwards a Hadamard gate is applied to qubit 0 to put it into a superposition state $\frac{\ket{0} + \ket{1}}{\sqrt{2}} \bra{0} + \frac{\ket{0} - \ket{1}}{\sqrt{2}} \bra{1}$.

# %%
circuit = qiskit.QuantumCircuit(2)
circuit.h(0)
circuit.h(1)
circuit.cx(0,1)
circuit.measure_all()

circuit.draw(output='mpl')

# %% [markdown]
# ## Measurement

# %%
job = qiskit.execute(circuit, simulator, shots=1000)
result = job.result()

qiskit.visualization.plot_histogram(result.get_counts())

# %% [markdown]
# $\require{\physics}$

# %%
$\bra{1}$
# Out:
#   File "<ipython-input-35-f5b1fbd6c079>", line 1
#     $\bra{1}$
#     ^
# SyntaxError: invalid syntax
